# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/RNN-practice/ch02
# Out:
# /content/drive/MyDrive/RNN-practice/ch02

# %%
import sys
sys.path.append("..")
from common.optimizer import SGD
from dataset import spiral
from ch01.two_layer_net import TwoLayerNet
from common import config
print(config.GPU)
config.GPU = True
print(config.GPU)
from common.trainer import Trainer


# 하이퍼파라미터 설정
max_epoch = 1000
batch_size = 30
hidden_size = 10
learning_rate = 0.1

x, t = x, t = spiral.load_data()
model = model = TwoLayerNet(input_size=2, hidden_size=hidden_size, output_size=3)
optimizer = SGD(lr=learning_rate)


trainer = Trainer(model, optimizer)
trainer.fit(x, t, max_epoch, batch_size, eval_interval=100)
trainer.plot()
# Out:
# True
# True
# | 에폭 1 |  반복 1 / 10 | 시간 0[s] | 손실 1.22
# | 에폭 2 |  반복 1 / 10 | 시간 0[s] | 손실 1.28
# | 에폭 3 |  반복 1 / 10 | 시간 0[s] | 손실 1.22
# | 에폭 4 |  반복 1 / 10 | 시간 0[s] | 손실 1.21
# | 에폭 5 |  반복 1 / 10 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 1 / 10 | 시간 0[s] | 손실 1.16
# | 에폭 7 |  반복 1 / 10 | 시간 0[s] | 손실 1.13
# | 에폭 8 |  반복 1 / 10 | 시간 0[s] | 손실 1.12
# | 에폭 9 |  반복 1 / 10 | 시간 0[s] | 손실 1.10
# | 에폭 10 |  반복 1 / 10 | 시간 0[s] | 손실 1.09
# | 에폭 11 |  반복 1 / 10 | 시간 0[s] | 손실 1.06
# | 에폭 12 |  반복 1 / 10 | 시간 0[s] | 손실 1.07
# | 에폭 13 |  반복 1 / 10 | 시간 0[s] | 손실 1.04
# | 에폭 14 |  반복 1 / 10 | 시간 0[s] | 손실 1.04
# | 에폭 15 |  반복 1 / 10 | 시간 0[s] | 손실 1.02
# | 에폭 16 |  반복 1 / 10 | 시간 0[s] | 손실 1.01
# | 에폭 17 |  반복 1 / 10 | 시간 0[s] | 손실 1.00
# | 에폭 18 |  반복 1 / 10 | 시간 0[s] | 손실 1.00
# | 에폭 19 |  반복 1 / 10 | 시간 0[s] | 손실 0.98
# | 에폭 20 |  반복 1 / 10 | 시간 0[s] | 손실 0.97
# | 에폭 21 |  반복 1 / 10 | 시간 0[s] | 손실 0.96
# | 에폭 22 |  반복 1 / 10 | 시간 0[s] | 손실 0.96
# | 에폭 23 |  반복 1 / 10 | 시간 0[s] | 손실 0.95
# ...
